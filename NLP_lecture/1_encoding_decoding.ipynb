# %% [markdown]
# ## 시스템의 인코딩 방식을 확인하기

# %%
import sys

print(sys.stdin.encoding)

print(sys.stdout.encoding)
# Out:
# utf-8
# UTF-8

# %% [markdown]
# ## 코드에서 인코딩을 설정해서 실행하는 주석
#
# * python 3.7 버전이하
# * python 3.8 버전 이상부터는 기본이 utf-8임

# %%
# -*- coding: utf-8 -*- # 가장 많이 사용(100%)
# -*- coding: latin-1 -*-

# %% [markdown]
# ## 기본 파이썬 패키지 활용
#
# ### 유니코드
#
# ord() : 특정문자의 유니코드 값을 확인
# chr() : 유니코드 값을 문자로 확인

# %%
print(ord('가'))
# Out:
# 44032

# %%
chr(44032)
# Out:
# '가'

# %% [markdown]
# ## 인코딩

# %%
str_data = '가나다라'
print(type(str_data))

str_data_encoded = str_data.encode('utf-8')
print(type(str_data_encoded))
print(str_data_encoded)
# Out:
# <class 'str'>
# <class 'bytes'>
# b'\xea\xb0\x80\xeb\x82\x98\xeb\x8b\xa4\xeb\x9d\xbc'

# %% [markdown]
# ## 디코딩

# %%
str_data_decoded = str_data_encoded.decode('utf-8')
print(type(str_data_decoded))
print(str_data_decoded)
# Out:
# <class 'str'>
# 가나다라

# %%
print(str_data)
# Out:
# 가나다라

# %%
type(1), type('1') , '1'
# Out:
# (int, str, '1')

# %% [markdown]
# ## 유니코드를 base64로 인코딩 및 디코딩하기

# %%
import base64

text_a = "Hello World!"
text_b = "Hello Python"

print(text_a)
print(text_b)

a_encode_unicode = text_a.encode('utf-8')
b_encode_unicode = text_b.encode('utf-8')

print(a_encode_unicode)
print(b_encode_unicode)

a_encode_base64 = base64.b64encode(a_encode_unicode)
b_encode_base64 = base64.b64encode(b_encode_unicode)

print(a_encode_base64)
print(b_encode_base64)
# Out:
# Hello World!
# Hello Python
# b'Hello World!'
# b'Hello Python'
# b'SGVsbG8gV29ybGQh'
# b'SGVsbG8gUHl0aG9u'

# %%
a_decode_unicode = a_encode_base64.decode('utf-8')
b_decode_unicode = b_encode_base64.decode('utf-8')

print(a_decode_unicode)
print(b_decode_unicode)

a_decode_base64 = base64.b64decode(a_decode_unicode)
b_decode_base64 = base64.b64decode(b_decode_unicode)

print(a_decode_base64)
print(b_decode_base64)
# Out:
# SGVsbG8gV29ybGQh
# SGVsbG8gUHl0aG9u
# b'Hello World!'
# b'Hello Python'

# %% [markdown]
# ## chardet 라이브러리 사용하기
#
# * encoding : 인코딩 예측 결과
# * confidence : 신뢰도(언어의 확률 분포에 기반하여 계산)
# * language : 언어 종류

# %%
pip install chardet
# Out:
# Requirement already satisfied: chardet in c:\programdata\anaconda3\lib\site-packages (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib
import chardet

# %%
url_path = 'https://ko.wikipedia.org/wiki/%EC%9E%90%EC%97%B0%EC%96%B4_%EC%B2%98%EB%A6%AC'

# %%
raw_data = urllib.request.urlopen(url_path).read()
raw_data
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled vector-feature-client-preferences-disabled" lang="ko" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>\xec\x9e\x90\xec\x97\xb0\xec\x96\xb4 \xec\xb2\x98\xeb\xa6\xac - \xec\x9c\x84\xed\x82\xa4\xeb\xb0\xb1\xea\xb3\xbc, \xec\x9a\xb0\xeb\xa6\xac \xeb\xaa\xa8\xeb\x91\x90\xec\x9d\x98 \xeb\xb0\xb1\xea\xb3\xbc\xec\x82\xac\xec\xa0\x84</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled vector-feature-client-preferences-disabled";var cookie=document.cookie.match(/(?:^|; )kowikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"ko","wgMonthNames":["","1\xec\x9b\x94","2\xec\x9b\x94","3\xec\x9b\x94",\n"4\xec\x9b\x94","5\xec\x9b\x94","6\xec\x9b\x94","7\xec\x9b\x94","8\xec\x9b\x94","9\xec\x9b\x94","10\xec\x9b\x94","11\xec\x9b\x94","12\xec\x9b\x94"],"wgRequestId":"ee282aed-a303-4658-bc90-aa83535301fb","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"\xec\x9e\x90\xec\x97\xb0\xec\x96\xb4_\xec\xb2\x98\xeb\xa6\xac","wgTitle":"\xec\x9e\x90\xec\x97\xb0\xec\x96\xb4 \xec\xb2\x98\xeb\xa6\xac","wgCurRevisionId":34907607,"wgRevisionId":34907607,"wgArticleId":177102,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["\xec\x9c\x84\xed\x82\xa4\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xec\x86\x8d\xec\x84\xb1 P373\xec\x9d\x84 \xec\x82\xac\xec\x9a\xa9\xed\x95\x98\xeb\x8a\x94 \xeb\xac\xb8\xec\x84\x9c","\xec\x9c\x84\xed\x82\xa4\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xec\x86\x8d\xec\x84\xb1 P244\xeb\xa5\xbc \xec\x82\xac\xec\x9a\xa9\xed\x95\x98\xeb\x8a\x94 \xeb\xac\xb8\xec\x84\x9c","\xec\x9c\x84\xed\x82\xa4\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xec\x86\x8d\xec\x84\xb1 P349\xeb\xa5\xbc \xec\x82\xac\xec\x9a\xa9\xed\x95\x98\xeb\x8a\x94 \xeb\xac\xb8\xec\x84\x9c","\xec\x9c\x84\xed\x82\xa4\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xec\x86\x8d\xec\x84\xb1 P691\xec\x9d\x84 \xec\x82\xac\xec\x9a\xa9\xed\x95\x98\xeb\x8a\x94 \xeb\xac\xb8\xec\x84\x9c","\xec\x9c\x84\xed\x82\xa4\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0 \xec\x86\x8d\xec\x84\xb1 P8189\xeb\xa5\xbc \xec\x82\xac\xec\x9a\xa9\xed\x95\x98\xeb\x8a\x94 \xeb\xac\xb8\xec\x84\x9c","\xec\xb6\x9c\xec\xb2\x98\xea\xb0\x80 \xed\x95\x84\xec\x9a\x94\xed\x95\x9c \xea\xb8\x80/2010\xeb\x85\x84 10\xec\x9b\x94","\xec\xb6\x9c\xec\xb2\x98\xea\xb0\x80 \xed\x95\x84\xec\x9a\x94\xed\x95\x9c \xeb\xaa\xa8\xeb\x93\xa0 \xea\xb8\x80","\xec\xa0\x84\xec\xb2\xb4\xec\x97\x90 \xec\xb6\x9c\xec\xb2\x98\xea\xb0\x80 \xed\x95\x84\xec\x9a\x94\xed\x95\x9c \xea\xb8\x80","J9U \xec\x8b\x9d\xeb\xb3\x84\xec\x9e\x90\xeb\xa5\xbc \xed\x8f\xac\xed\x95\xa8\xed\x95\x9c \xec\x9c\x84\xed\x82\xa4\xeb\xb0\xb1\xea\xb3\xbc \xeb\xac\xb8\xec\x84\x9c","LCCN \xec\x8b\x9d\xeb\xb3\x84\xec\x9e\x90\xeb\xa5\xbc \xed\x8f\xac\xed\x95\xa8\xed\x95\x9c ...

# %%
chardet.detect(raw_data)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
print(b_encode_base64)
print(chardet.detect(b_encode_base64))
# Out:
# b'SGVsbG8gUHl0aG9u'
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}
